# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.cm import get_cmap
import seaborn as sns
import string
import pickle # save data frame (results) in a .pkl file
import pandas as pd
from datetime import datetime
import os, sys
import re


sys.path.insert(0, 'C:/Users/User/Code/MMDGraph')
#from importlib import reload
from mmdutils import readfoldertopanda, PlotROCGeneral, plotVaryingBGDEG, findAUC
#reload(readfoldertopanda)
import importlib
importlib.reload(sys.modules['mmdutils'])
from mmdutils import readfoldertopanda, PlotROCGeneral, plotVaryingBGDEG, findAUC

# %%
keys = ['nr_nodes_1', 'nr_nodes_2', 'ar1','ar2', 'n', 'm']
params_kernel = {}
data_auc = {}
data = {}

# %%
data['RW'] = readfoldertopanda("../data/ARseries")
data['RW'].columns
# Out:
# Index(['alpha', 'normalize', 'ar1', 'ar2', 'var1', 'var2', 'n', 'm', 'B', 'N',
#        'MMDu_nbb_2', 'MMDu_nbb_3', 'MMDu_nbb_4', 'MMDu_nbb_5', 'MMDu_nbb_7',
#        'MMDu_nbb_10', 'MMDu_nbb_12', 'MMDu_nbb_15', 'MMDu_nbb_20',
#        'MMDu_wild_1', 'MMDu_wild_2', 'MMDu_wild_5', 'MMDu'],
#       dtype='object')

# %%
data['RW']['ar2']
# Out:
# 0      0.7
# 1      0.7
# 2      0.7
# 3      0.7
# 4      0.7
#       ...
# 994    0.9
# 995    0.9
# 996    0.9
# 997    0.9
# 998    0.9
# Name: ar2, Length: 4995, dtype: float64

# %%
fig, ax = plt.subplots(1,1, figsize = (30, 10))
data_plot = data['RW'].loc[(data['RW']['ar1'] == 0.9) & (data['RW']['ar2'] == 0.7)]

ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_2'], label = 'NNB 2')
#ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_3'], label = 'NNB 3')
#ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_4'], label = 'NNB 4')
ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_5'], label = 'NNB 5')
#ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_7'], label = 'NNB 7')
#ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_10'], label = 'NNB 10')
#ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_12'], label = 'NNB 12')
#ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_15'], label = 'NNB 15')
#ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_20'], label = 'NNB 20')

ax.plot(data_plot['alpha'], data_plot['MMDu_wild_1'], label = 'Wild 1')

ax.plot(data_plot['alpha'], data_plot['MMDu_wild_2'], label = 'Wild 2')

ax.plot(data_plot['alpha'], data_plot['MMDu_wild_5'], label = 'Wild 5')

ax.plot(data_plot['alpha'], data_plot['MMDu'], label = 'Perm')

ax.legend()

# %%
fig, ax = plt.subplots(1,1, figsize = (30, 10))
data_plot = data['RW'].loc[data['RW']['ar1'] == 0.9]

ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_2'], label = 'NNB 2')
#ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_3'], label = 'NNB 3')
#ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_4'], label = 'NNB 4')
ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_5'], label = 'NNB 5')
#ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_7'], label = 'NNB 7')
#ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_10'], label = 'NNB 10')
#ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_12'], label = 'NNB 12')
#ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_15'], label = 'NNB 15')
#ax.plot(data_plot['alpha'], data_plot['MMDu_nbb_20'], label = 'NNB 20')

ax.plot(data_plot['alpha'], data_plot['MMDu_wild_1'], label = 'Wild 1')

ax.plot(data_plot['alpha'], data_plot['MMDu_wild_2'], label = 'Wild 2')

ax.plot(data_plot['alpha'], data_plot['MMDu_wild_5'], label = 'Wild 5')

ax.plot(data_plot['alpha'], data_plot['MMDu'], label = 'Perm')

ax.legend()
